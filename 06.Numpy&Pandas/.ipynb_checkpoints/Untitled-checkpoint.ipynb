# %% [markdown]
# 1. numpy
# 2. pandas
# 3. matplotlib

# %% [markdown]
# # numpy

# %%
#numpy_generate 
import numpy as np

#from list to numpy
a_list=list(range(10))
b=np.array(a_list)

# generate array
a = np.zeros(10)
print(type(a))

# generate int array
a = np.zeros(10, dtype=int)
a.dtype

# generate 2D array
a = np.zeros((4,3), dtype=float) #4 rows*3 cols

# generate 2D array with "3.14"
a = np.full((3,2), 3.14)  # 3 rows*2 cols with value 3.14

# based on an array, generate anotehr one
np.full_like(a,4.12, dtype=float)   # based on a, change value to 4.12

#np.random
np.random.random()   # generate a random num
np.random.random((3,3))   # generate a 3*3 array random num 
np.random.randint(0,10,(5,5)) # generate a 5*% array random num between 0 ~10

# range
np.arange(0,10,2)  # return array([0,2,4,6,8])

# linespace: same difference between any two subsiquent numbers
np.linspace(0,3, 10 ) #return array([0., 0.33333333, 0.66666667, 1., 1.33333333,1.66666667, 2., 2.33333333, 2.66666667, 3.])

# geneate identity matrix
np.eye(10)  # return 10*10 identity matrix

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#numpy_query

a=np.full((3,3),3.14)

#query one element 
a[-1][0]   #a[row][col]
#OR
a[-1,0]    #a[row, col]

#query a few cols/rows
a[:2]     # first 2 rows
a[:2,:2]  # first 2 rows && first 2 cols

# %%
# property of numpy array:
a=np.full((3,3),3.14)

a.ndim # dimention of the array, eg:2
a.shape # shape of the array, eg:(3,3)
a.size  # size of the array, eg:9
a.dtype #dtype eg: float
a.itemsize #every itemsize, eg: 8
a.nbytes #total bytes, eg: 72

# %%
# np calculation

a= np.array(list(range(10)))

a+10  # all items +10

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# statics 
a= np.full((10,10), 2.3)

# np sum
np.sum(a)  # return 1 value 
np.sum(a, axis=0)  # sum of each col
np.sum(a, axis=1)  # sum of each row

#max / min
np.max(a,axis=0)

# %%
# compare
a= np.array(range(10))

a>3 #return array([False, False, False, False,  True,  True,  True,  True,  True, True])

np.all(a>-1) # return True
np.any(a>-1) # return  True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Reshape array
a= np.full((2,10),1) # 2 rows*10 col
a.reshape(10,2) #10 rows *2 cols
a.reshape(4,5)  # 4 rows * 5 cols

# %%
# Sorting 

l=[
    [1,2,3],
    [32,12,4],
    [32,2,33]
]
a=np.array(l)

np.sort(a) #generate a new returned type with each row sorted 
a.sort(axis=0) # sort each col
a.sort(axis=1) # sort each row

# %%
# combine 2 array to 1

a= np.array([1,2,3])
b=np.array([[0,2,4],[1,3,5]])

np.concatenate([a,a,a], axis=0) # merge all rows vertically
np.concatenate([a,a,a], axis=1) # merge all rows horizontallu

# %% [markdown]
# # pandas

# %%
import pandas as pd

#read
df = pd.read_csv('C:/Users/yanbi/Desktop/Sum_Research2/National data/All_澳门特别行政区.csv')
df.head(2) # read first 2 rows 

# all col names:
df.columns
# see how many data rows in total
df.index
#see a row of data 
df.loc[0]

# %%
# filter 
df[df.留言状态 == "待回复"]

#complax filter
df[(df.留言状态 == "待回复") & (df.省份 == "澳门特别行政区")]

# %%
# sort
df.sort_values(['留言时间'])  #按“留言时间” 来排序
df.sort_values(['留言时间','留言标题'])  #先按“留言时间” 来排序，再按“留言标题” 来排序

# %%
# query
df.loc[3]  # if the index ==3 # below**
df.iloc[3] # will take 4th row 
df.ix[3]  # combine .loc and .iloc; if can find number index 0, then return, if not, return iloc[0]

#df[2]    WRONG!!!
df[:2]   # first 2 rows

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# convert all data to array
df.values

# simple counts
df.留言对象.values_counts()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# extract multiple columns:
a= df[['留言对象','留言时间']].head(2)
# Out:
#              留言对象              留言时间
# 0  澳门特别行政区行政长官贺一诚  2013-08-19 14:22
# 1  澳门特别行政区行政长官贺一诚  2013-09-23 16:34

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# map
# 对一列数据操作
# see below

# applymap
# 对全部数据操作
# see below

#apply 
#根据多列新生成一个列
# see below

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # matplotlib #

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
# above line is a must write, to plot in the notebook

# %%
x=np.linspace (0,10,4)
y=np.sin(x)

plt.plot(x,y)
plt.plot(x,np.cos(x), "--")

# %%
fig = plt.figure()
plt.plot(x,y,"--")

# save the pic 
fig.savefig('/C:/Path/name.png')

# %%
plt.subplot(2,1,2)
plt.plot(x, np.sin(x), '--') #"-----"

plt.subplot(2,1,1)
plt.plot(x,np.cos(x),'o',color=r'red') #"....."

# %%
# add label
x = np.linspace(0, 10, 10)
y = np.sin(x)

plt.plot(x, y, label='sin(x)')
plt.plot(x, np.cos(x), "--", label='cos(x)')
plt.legend(loc=1)
# for more: plt.legend?
# plt.legend?

# control other attributes
plt.plot(x,y,'-p',color='orange', markersize=16, linewidth=4, markeredgecolor='grey',markeredgewidth=2)

# control plot range 
plt.ylim(-0.5,1.2)
plt.xlim(-0.5,1.2)
# Out:
# (-0.5, 1.2)

# %%
# different types of graphs:
x = np.linspace(0, 10, 10)
y = np.sin(x)

# scatter graph
plt.scatter(x,y,s=10)

# scatter graph example
plt.style.use('classic')

x=np.random.randn(100)
y=np.random.randn(100)
colors=np.random.rand(100)
sizes = 1000* np.random.rand(100)
plt.scatter(x,y,c=colors, s=sizes, alpha=0.4)
plt.colorbar()

# %% [markdown]
# # pandas plotting graph

# %%
#线型图
df = pd.DataFrame(np.random.rand(100, 4).cumsum(0), columns=['A','B','C','D'])
df.plot()

# %%
df.A.plot()

# %%
#柱状图
df = pd.DataFrame(np.random.randint(10,50,(3,4)),columns=['A','B','C','D'], index=['one','two','three'])
print(df)
df.plot.bar()
# Out:
#         A   B   C   D
# one    23  39  14  27
# two    49  35  26  43
# three  32  17  21  11

# %%
df.B.plot.bar()

# %%
df.plot(kind='bar',stacked=True)

# %%
# 直方图
df=pd.DataFrame(np.random.randn(10,4),columns=['A','B','C','D'])
print (df)
df.hist()
df.hist(column='A')
df.hist(column='A', grid=False)
# Out:
#           A         B         C         D
# 0  0.557912 -1.962532 -0.564527 -1.059197
# 1  0.067713  0.109335 -1.662251  0.034229
# 2 -0.350506 -1.402755 -0.638608 -2.276751
# 3  0.636618  1.107605 -2.152426  0.694012
# 4 -1.044794  0.444810 -0.848423 -0.223184
# 5  0.393367 -0.544026  0.859676 -0.011160
# 6  1.916419 -0.082006  0.692187  1.765630
# 7 -0.518083 -1.435175  1.422064  0.630976
# 8 -1.640657 -2.005026  2.760925  1.031072
# 9  0.927046  1.221376 -0.655551 -0.863563
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002162222D708>]],
#       dtype=object)

# %%
#密度图
df=pd.DataFrame(np.random.randn(10,4),columns=['A','B','C','D'])
print(df)

df.plot.kde(grid=True, figsize=(6,6))
# ===
df.plot(kind='kde')
# Out:
#           A         B         C         D
# 0  0.144873 -0.934247  0.636478  0.541470
# 1  0.979588  0.168055 -0.598080  0.626197
# 2  0.785619 -1.861797 -0.618187  0.101300
# 3  0.889325 -0.331652  0.886110 -0.469827
# 4  0.709770  0.954476 -0.376799 -1.126578
# 5 -1.159621  1.199881 -0.407068 -0.253518
# 6  0.367380  0.616723 -0.942102 -0.015693
# 7 -0.529324 -0.936607  0.256530 -0.100675
# 8  0.010210 -0.322210 -1.383608 -0.713257
# 9  2.475119  0.062967 -0.564707  0.176287

# %%
#3D graph

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np

fig=plt.figure()
ax=fig.gca(projection='3d')

#make data
X=np.arange(-5,5,0.25)
Y=np.arange(-5,5,0.25)
X,Y=np.meshgrid(X,Y)
R=np.sqrt(X**2+Y**2)
Z=np.sin(R)

#Plot the surface
surf=ax.plot_surface(X,Y,Z,cmap=cm.coolwarm,
                    linewidth=0, antialiased=False)

#Customize the z axis
ax.set_zlim(-1.01,1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
                                 
#Add a color bar which maps values to colors
fig.colorbar(surf, shrink=0.5, aspect=5)
                                  
plt.show()
